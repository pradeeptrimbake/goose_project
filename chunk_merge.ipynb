# %%
import os
import math
import pandas as pd
from pathlib import Path
import numpy as np
import os
import matplotlib.pyplot as plt
import h5py
import glob

# %%
g17 = [0,3,13,14,18,28,29,33,43,44,48,58,59,63,73,74,78,88,89,93,103,104,108,118,119,123,133,134,138,148,149,153,163,164,168,178,179,183,193,194,198,208,209,213,223,224,228,238,239,243,253,254]
g16 = [0,3,13,14,18,28,29,33,43,44,48,58,59,63,73,74,78,88,89,93,103,104,108,118,119,123,133,134,138,148,149,153,163,164,168,178,179,183,193,194,198,208,209,213,223,224,228,238,239]
g15 = [0,3,13,14,18,28,29,33,43,44,48,58,59,63,73,74,78,88,89,93,103,104,108,118,119,123,133,134,138,148,149,153,163,164,168,178,179,183,193,194,198,208,209,213,223,224]
g14 = [0,3,13,14,18,28,29,33,43,44,48,58,59,63,73,74,78,88,89,93,103,104,108,118,119,123,133,134,138,148,149,153,163,164,168,178,179,183,193,194,198,208,209]
g13 = [0,3,13,14,18,28,29,33,43,44,48,58,59,63,73,74,78,88,89,93,103,104,108,118,119,123,133,134,138,148,149,153,163,164,168,178,179,183,193,194]
g12 = [0,3,13,14,18,28,29,33,43,44,48,58,59,63,73,74,78,88,89,93,103,104,108,118,119,123,133,134,138,148,149,153,163,164,168,178,179]
g11 = [0,3,13,14,18,28,29,33,43,44,48,58,59,63,73,74,78,88,89,93,103,104,108,118,119,123,133,134,138,148,149,153,163,164]
g10 = [0,3,13,14,18,28,29,33,43,44,48,58,59,63,73,74,78,88,89,93,103,104,108,118,119,123,133,134,138,148,149]
g9 = [0,3,13,14,18,28,29,33,43,44,48,58,59,63,73,74,78,88,89,93,103,104,108,118,119,123,133,134]
g8 = [0,3,13,14,18,28,29,33,43,44,48,58,59,63,73,74,78,88,89,93,103,104,108,118,119]
g7 = [0,3,13,14,18,28,29,33,43,44,48,58,59,63,73,74,78,88,89,93,103,104]
g6 = [0,3,13,14,18,28,29,33,43,44,48,58,59,63,73,74,78,88,89]
g5 = [0,3,13,14,18,28,29,33,43,44,48,58,59,63,73,74]
g4 = [0,3,13,14,18,28,29,33,43,44,48,58,59]
g3 = [0,3,13,14,18,28,29,33,43,44]
g2 = [0,3,13,14,18,28,29]
g1 = [0,3,13,14]

path = r'C:\Users\labgrprattenborg\Desktop\Pradeep\20220919_DLC_extract'  # or unix / linux / mac path

# %%
try:
    files = Path(path).glob('bs6173_1d*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220725_DLC_extract/merge/6173/20220725_bs6173_01.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_2d*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_02.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_3d*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_03.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_4d*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_04.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_5d*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_05.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_6d*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_06.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_7d*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_07.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_8d*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_08.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_9d*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_09.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_10*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_10.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_11*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_11.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_12*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_12.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_13*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_13.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_14*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_14.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_15*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_15.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_16*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_16.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_17*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_17.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_18*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_18.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_19*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_19.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_20*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_20.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_21*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_21.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_22*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_22.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_23*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_23.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_24*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_24.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_25*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_25.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_26*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_26.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_27*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_27.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_28*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_28.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_29*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_29.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_30*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_30.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_31*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_31.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_32*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_32.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_33*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_33.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_34*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_34.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_35*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_35.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_36*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_36.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_37*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_37.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_38*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_38.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_39*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_39.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_40*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_40.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_41*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_41.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_42*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_42.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_43*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_43.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_44*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_44.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_45*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_45.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_46*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_46.csv')
except ValueError:
    print('error')

# %%
try:
    files = Path(path).glob('bs6196_47*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_47.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_48*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_48.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_49*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_49.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_50*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_50.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_51*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_51.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_52*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_52.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_53*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_53.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_54*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_54.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_55*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_55.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_56*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_56.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_57*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_57.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_58*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_58.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_59*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_59.csv')
except ValueError:
    print('error')
# Out:
# error

# %%
try:
    files = Path(path).glob('bs6196_60*.csv')  # .rglob to get subdirectories

    dfs = list()
    for f in files:
        data = pd.read_csv(f)
        # .stem is method for pathlib objects to get the filename w/o the extension
        dfs.append(data)

    df = pd.concat(dfs, ignore_index=False, axis=1)
    dflen = len(df.columns)

    if dflen == 255:
        df_new = df.iloc[:,g17]
    elif dflen == 240:
        df_new = df.iloc[:, g16]
    elif dflen == 225:
        df_new = df.iloc[:, g15]
    elif dflen == 210:
        df_new = df.iloc[:, g14]
    elif dflen == 195:
        df_new = df.iloc[:, g13]
    elif dflen == 180:
        df_new = df.iloc[:, g12]
    elif dflen == 165:
        df_new = df.iloc[:, g11]
    elif dflen == 150:
        df_new = df.iloc[:, g10]
    elif dflen == 135:
        df_new = df.iloc[:, g9]
    elif dflen == 120:
        df_new = df.iloc[:, g8]
    elif dflen == 105:
        df_new = df.iloc[:, g7]
    elif dflen == 90:
        df_new = df.iloc[:, g6]
    elif dflen == 75:
        df_new = df.iloc[:, g5]
    elif dflen == 60:
        df_new = df.iloc[:, g4]
    elif dflen == 45:
        df_new = df.iloc[:, g3]
    elif dflen == 30:
        df_new = df.iloc[:, g2]
    else:
        df_new = df.iloc[:, g1]
        

    df_new = df_new.replace( to_replace= "Right Open", value=2)
    df_new = df_new.replace( to_replace= "Left Open", value=2)
    df_new = df_new.replace( to_replace= "Right Close", value=3)
    df_new = df_new.replace( to_replace= "Left Close", value=3)
    df_new = df_new.replace( to_replace= "Right Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Left Out of Sight", value=1)
    df_new = df_new.replace( to_replace= "Not sure", value=0)

    df_new.to_csv('C:/Users/labgrprattenborg/Desktop/Pradeep/20220919_DLC_extract/merge/6196/20220919_bs6196_60.csv')
except ValueError:
    print('error')
# Out:
# error
