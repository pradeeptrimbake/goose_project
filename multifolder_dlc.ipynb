# %%
import deeplabcut
import os

# %%
project_name = "gooseproj2022"
experimenter = "grprattenborg"
config_path = "L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\config.yaml"

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6165_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6165_down\bs6165_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6165_down\bs6165_10downsampledcropped.mp4
# Duration of video [s]:  82.96 , recorded with  25.0 fps!
# Overall # of frames:  2074  found with (before cropping) frame dimensions:  1500 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 2074/2074 [02:16<00:00, 15.19it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6165_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6167_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6167_down\bs6167_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6167_down\bs6167_10downsampledcropped.mp4
# Duration of video [s]:  44.2 , recorded with  25.0 fps!
# Overall # of frames:  1105  found with (before cropping) frame dimensions:  1460 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 1105/1105 [01:08<00:00, 16.25it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6167_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6169_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6169_down\bs6169_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6169_down\bs6169_10downsampledcropped.mp4
# Duration of video [s]:  121.96 , recorded with  25.0 fps!
# Overall # of frames:  3049  found with (before cropping) frame dimensions:  1500 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 3049/3049 [03:14<00:00, 15.67it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6169_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6170_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6170_down\bs6170_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6170_down\bs6170_10downsampledcropped.mp4
# Duration of video [s]:  115.52 , recorded with  25.0 fps!
# Overall # of frames:  2888  found with (before cropping) frame dimensions:  1460 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 2888/2888 [02:58<00:00, 16.18it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6170_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6171_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6171_down\bs6171_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6171_down\bs6171_10downsampledcropped.mp4
# Duration of video [s]:  56.0 , recorded with  25.0 fps!
# Overall # of frames:  1400  found with (before cropping) frame dimensions:  1500 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 1400/1400 [01:26<00:00, 16.17it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6171_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6172_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6172_down\bs6172_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6172_down\bs6172_10downsampledcropped.mp4
# Duration of video [s]:  44.2 , recorded with  25.0 fps!
# Overall # of frames:  1105  found with (before cropping) frame dimensions:  1460 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 1105/1105 [01:06<00:00, 16.50it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6172_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6173_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6173_down\bs6173_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6173_down\bs6173_10downsampledcropped.mp4
# Duration of video [s]:  40.04 , recorded with  25.0 fps!
# Overall # of frames:  1001  found with (before cropping) frame dimensions:  1500 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 1001/1001 [01:00<00:00, 16.57it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6173_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6174_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6174_down\bs6174_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6174_down\bs6174_10downsampledcropped.mp4
# Duration of video [s]:  299.93 , recorded with  29.97 fps!
# Overall # of frames:  8989  found with (before cropping) frame dimensions:  1460 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 8989/8989 [09:05<00:00, 16.49it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6174_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6175_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6175_down\bs6175_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6175_down\bs6175_10downsampledcropped.mp4
# Duration of video [s]:  115.52 , recorded with  25.0 fps!
# Overall # of frames:  2888  found with (before cropping) frame dimensions:  1500 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 2888/2888 [02:52<00:00, 16.69it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6175_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6189_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6190_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6190_down\bs6190_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6190_down\bs6190_10downsampledcropped.mp4
# Duration of video [s]:  109.8 , recorded with  25.0 fps!
# Overall # of frames:  2745  found with (before cropping) frame dimensions:  1460 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 2745/2745 [02:43<00:00, 16.82it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6190_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6191_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6191_down\bs6191_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6191_down\bs6191_10downsampledcropped.mp4
# Duration of video [s]:  40.04 , recorded with  25.0 fps!
# Overall # of frames:  1001  found with (before cropping) frame dimensions:  1460 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 1001/1001 [00:59<00:00, 16.84it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6191_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6192_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6192_down\bs6192_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6192_down\bs6192_10downsampledcropped.mp4
# Duration of video [s]:  121.96 , recorded with  25.0 fps!
# Overall # of frames:  3049  found with (before cropping) frame dimensions:  1460 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 3049/3049 [03:00<00:00, 16.92it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6192_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6193_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6193_down\bs6193_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6193_down\bs6193_10downsampledcropped.mp4
# Duration of video [s]:  109.8 , recorded with  25.0 fps!
# Overall # of frames:  2745  found with (before cropping) frame dimensions:  1500 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 2745/2745 [02:59<00:00, 15.31it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6193_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6194_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6194_down\bs6194_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6194_down\bs6194_10downsampledcropped.mp4
# Duration of video [s]:  72.36 , recorded with  25.0 fps!
# Overall # of frames:  1809  found with (before cropping) frame dimensions:  1460 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 1809/1809 [01:55<00:00, 15.61it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6194_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6195_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6195_down\bs6195_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6195_down\bs6195_10downsampledcropped.mp4
# Duration of video [s]:  72.36 , recorded with  25.0 fps!
# Overall # of frames:  1809  found with (before cropping) frame dimensions:  1500 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 1809/1809 [01:58<00:00, 15.25it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6195_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6196_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6196_down\bs6196_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6196_down\bs6196_10downsampledcropped.mp4
# Duration of video [s]:  299.96 , recorded with  25.0 fps!
# Overall # of frames:  7499  found with (before cropping) frame dimensions:  1500 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 7499/7499 [08:04<00:00, 15.48it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6196_down...
# ...

# %%
lst=[]
cwd = 'H:/20220919_chunks/bs6197_down'
for file in os.listdir(cwd):
    if file.endswith("cropped.mp4"):
        lst.append(file)

for vids in lst:
    deeplabcut.analyze_videos(config_path, os.path.join(cwd, vids), videotype='.mp4', auto_track=False)
    deeplabcut.convert_detections2tracklets(config_path, os.path.join(cwd, vids), videotype='.mp4')
# Out:
# Using snapshot-200000 for model L:\gooseproject15092022\gooseproj2022-grprattenborg-2022-09-15\dlc-models\iteration-0\gooseproj2022Sep15-trainset95shuffle1
# c:\Users\labgrprattenborg\Anaconda3\envs\DEEPLABCUT\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Activating extracting of PAFs
# Starting to analyze %  H:/20220919_chunks/bs6197_down\bs6197_10downsampledcropped.mp4
# Loading  H:/20220919_chunks/bs6197_down\bs6197_10downsampledcropped.mp4
# Duration of video [s]:  299.96 , recorded with  25.0 fps!
# Overall # of frames:  7499  found with (before cropping) frame dimensions:  1500 880
# Starting to extract posture from the video(s) with batchsize: 8
# 100%|██████████| 7499/7499 [07:54<00:00, 15.79it/s]
# Video Analyzed. Saving results in H:\20220919_chunks\bs6197_down...
# ...
